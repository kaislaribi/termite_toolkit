# %% [markdown]
# # Python TERMite toolkit - TERMite

# %% [markdown]
# We provide a Python library for making calls to our NER engine, TERMite, as well as the TExpress module for defining more complex semantic patterns. The library also enables post-processing of the JSON returned from such requests. This notebook gives you the rundown on how to make a call to TERMite and some of the possible post-processing of the JSON output.

# %% [markdown]
# ## Install or update Python toolkit¶

# %% [markdown]
# The Python toolkit can simply be installed by running the following command in the terminal:
# ```
# pip3 install termite_toolkit
# ```
# If you already have the toolkit install make sure you have the latest version:
# ```
# pip3 install termite_toolkit --upgrade
# ```

# %% [markdown]
# ## Example call to TERMite

# %% [markdown]
# Making a call to TERMite with the toolkit is easy: simply ```import termite``` from the ```termite_toolkit``` and make a call.
#
# A call is made up of:
# * the TERMite API endpoint
# * the entities you wish to use for annotation
# * a TERMite request
# * request execution
#
# Save the TERMite call in a python script and simply run ```python ExampleCall.py``` in the terminal.

# %% [markdown]
# This is some example text we can make a TERMite call on

# %%
input_text = "The data in Table 2, Row 2 suggest that Telmisartan might be useful to prevent colon cancer (note that Clopidogrel is in both the Drug and Control arm, so we did not investigate Clopidogrel further). Recent cell-based studies reported that Telmisartan exerts anti-tumor effects by activating peroxisome proliferator-activated receptor-γ (Li et al., 2014; Pu, Zhu & Kong, 2016; Wu et al., 2016b). The algorithm presented here provides the first evidence from a randomized clinical trial indicating that Telmisartan may be viable as a repurposed prevention for colon cancer. Phylloquinone (Table 2, Row 4) is a vitamin (vitamin K1) supplement rather than a prescription drug. K vitamins + sorafenib induce apoptosis in human pancreatic cancer cell lines (Wei, Wang & Carr, 2010). A prospective cohort analysis found that individuals who increased their intake of dietary phylloquinone might have a lower risk of cancer than those who did not (Juanola-Falgarona et al., 2014). The data from the randomized trial in Table 2 suggest that vitamin K1 might actually help prevent cancer (OR = 0.27, 95% CI [0.07–0.98]). The potential cancer prevention by vitamin K1 is especially intriguing because one can get more than 1,000% daily value of vitamin K1 by simply eating one cup of cooked kale or spinach (https://www.healthaliciousness.com/articles/food-sources-of-vitamin-k.php)."

# %% [markdown]
# Below is an example TERMite call. The API endpoint specified is TERMite's default endpoint. Here we just print the TERMite result to the screen.

# %%
from pprint import pprint
from termite_toolkit import termite

# specify termite API endpoint
termite_home = "http://localhost:9090/termite"

# specify entities to annotate
entities = "DRUG,INDICATION"

# initialise a request builder
t = termite.TermiteRequestBuilder()

# add items to your TERMite request
t.set_url(termite_home)
t.set_text(input_text)  # this is where we send the text to be annotated
t.set_entities(entities)  # you must specify the vocab neams you would like to use for annotation
t.set_subsume(True)
t.set_input_format("txt")
t.set_output_format("json")  # you can try different output formats here e.g. "tsv"
t.set_reject_ambiguous(False)


# once the query object has been built, execute the TERMite request
termite_response = t.execute(display_request=False)

pprint(termite_response)
# Out:
# {'RESP_META': {'CONID': '127.0.0.1/68',
#                'ENTITIES_LIMIT': '[DRUG, INDICATION]',
#                'HTTP_CODE': '200',
#                'INPUT_SIZE': 1373,
#                'JSON_PRODUCER': 'EFFICIENT',
#                'REQID': 'd70829d1-bc8f-44ce-a2ee-39a19321a43a-14877',
#                'RUNTIME_OPTIONS': {'_termitesys.exetermite': 'true',
#                                    '_termitesys.exetexpress': 'false',
#                                    'rejectAmbig': 'false',
#                                    'subsume': 'true'},
#                'TERMITE_RUNTIME': 'default',
#                'TERMITE_VERS': '6.3.17',
#                'Timing_msec_TOTAL': '200'},
#  'RESP_PAYLOAD': {'DRUG': [{'dependencyMet': True,
#                             'dictSynList': ['telmisartan',
#                                             'telmisartan',
#                                             'telmisartan'],
#                             'docID': 'Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a43a-14879',
#                             'docTitle': '',
#                             'entityMeta': {'_ext_name': 'ChEMBL',
#                                            '_ext_uri': 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1017',
#                                            'parent_canonical_smiles': 'CCCc1nc2c(C)cc(cc2n1Cc3ccc(cc3)c4ccccc4C(=O)O)c5nc6ccccc6n5C',
#                                            'parent_std_inchi': 'InChI=1S/C33H30N4O2/c1-4-9-30-35-31-21(2)18-24(32-34-27-12-7-8-13-28(27)36(32)3)19-29(31)37(30)20-22-14-16-23(17-15-22)25-10-5-6-11-26(25)33(38)39/h5-8,10-19H,4,9,20H2,1-3H3,(H,38,39)',
#                                            'parent_std_inchi_key': 'RMMXLENWKUUMAY-UHFFFAOYSA-N'},
#                             'entityType': 'DRUG',
#                             'exact_array': [{'fls': [1, 40, 51]},
#                                             {'fls': [2, 240, 251]},
#                                             {'fls': [3, 502, 513]}],
#                             'exact_string': '1#40-51,2#240-251,3#502-513',
#                             'frag_vector_array': ['1#le 2, Row 2 suggest that '
#                                                   '{!Telmisartan!} might be '
#                                                   'useful to preve',
#                                                   '2#ed studies reported that '
#                                                   '{!Telmisartan!} exerts '
#                                                   'anti-tumor effect',
#                                                   '3#al trial indicating that '
#                                                   '{!Telmisartan!} may be '
#                                                   'viable as a repur'],
#                             'fuzzyMatches': 0,
#                             'goodSynCount': 3,
#                             'hitCount': 3,
#                             'hitID': 'CHEMBL1017',
#                             'hit_loc_vector': [1, 2, 3],
#                             'invalidPositions': False,
#                             'kvp': {'entityType': 'DRUG'},
#                             'mappings': ['DRUGBANK|DB00966|xRef',
#                                          'SCIBITE|DRUG:CHEMBL1017|seeAlso',
#                                          'INCHIKEY|RMMXLENWKUUMAYUHFFFAOYSAN|xRef',
#                                          'SMILES|CCCc1nc2cCcccc2n1Cc3ccccc3c4ccccc4COOc5nc6ccccc6n5C|xRef',
#                                          'IUPHAR|592|xRef',
#                                          'CHEMSPIDER|59391|xRef',
#                                          'PDB|TLS|xRef'],
#                             'name': 'Telmisartan',
#                             'nonambigsyns': 1,
#                             'realSynList': ['Telmisartan',
#                                             'Telmisartan',
#                                             'Telmisartan'],
#                             'rejected': False,
#                             'score': 4,
#                             'sourceID': '',
#                             'sourceTitle': '',
#                             'subsume': [False, False, False],
#                             'synState': [1, 1, 1],
#                             'taxon': {'CHEMBLATC': {'CHEMBL_ATC/C/C09/C09C/C09CA/C09CA07': 'CHEMBL_ATC/CARDIOVASCULAR '
#                                                                                            'SYSTEM/AGENTS '
#                                                                                            'ACTING '
#                                                                                            'ON '
#                                                                                            'THE '
#                                                                                            'RENIN-ANGIOTENSIN '
#                                                                                            'SYSTEM/ANGIOTENSIN '
#                                                                                            'II '
#                                                                                            'ANTAGONISTS, '
#                                                                                            'PLAIN/Angiotensin '
#                                                                                            'II '
#                                                                                            'antagonists, '
#                                                                                            'plain/telmisartan'}},
#                             'totnosyns': 1,
#                             'word_pos_array': [9, 6, 15]},
#                            {'dependencyMet': True,
#                             'dictSynList': ['sorafenib'],
#                             'docID': 'Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a43a-14879',
#                             'docTitle': '',
#                             'entityMeta': {'_ext_name': 'ChEMBL',
#                                            '_ext_uri': 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1336',
#                                            'parent_canonical_smiles': 'CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(c3)C(F)(F)F)cc2)ccn1',
#                                            'parent_std_inchi': 'InChI=1S/C21H16ClF3N4O3/c1-26-19(30)18-11-15(8-9-27-18)32-14-5-2-12(3-6-14)28-20(31)29-13-4-7-17(22)16(10-13)21(23,24)25/h2-11H,1H3,(H,26,30)(H2,28,29,31)',
#                                            'parent_std_inchi_key': 'MLDQJTXFUGDVEO-UHFFFAOYSA-N'},
#                             'entityType': 'DRUG',
#                             'exact_array': [{'fls': [5, 687, 696]}],
#                             'exact_string': '5#687-696',
#                             'frag_vector_array': ['5#K vitamins + '
#                                                   '{!sorafenib!} induce '
#                                                   'apoptosis in huma'],
#                             'fuzzyMatches': 0,
#                             'goodSynCount': 1,
#                             'hitCount': 1,
#                             'hitID': 'CHEMBL1336',
#                             'hit_loc_vector': [5],
#                             'invalidPositions': False,
#                             'kvp': {'entityType': 'DRUG'},
#                             'mappings': ['DRUGBANK|DB00398|xRef',
#                                          'SCIBITE|DRUG:CHEMBL1336|seeAlso',
#                                          'INCHIKEY|MLDQJTXFUGDVEOUHFFFAOYSAN|xRef',
#                                          'PHARMGKB|PA7000|xRef',
#                                          'SMILES|CNCOc1ccOc2cccNCONc3cccClcc3CFFFcc2ccn1|xRef',
#                                          'IUPHAR|5711|xRef',
#                                          'CHEMSPIDER|187440|xRef',
#                                          'PDB|BAX|xRef'],
#                             'name': 'BAY43-9006',
#                             'nonambigsyns': 1,
#                             'realSynList': ['sorafenib'],
#                             'rejected': False,
#                             'score': 1,
#                             'sourceID': '',
#                             'sourceTitle': '',
#                             'subsume': [False],
#                             'synState': [1],
#                             'taxon': {'CHEMBLATC': {'CHEMBL_ATC/L/L01/L01X/L01XE/L01XE05': 'CHEMBL_ATC/ANTINEOPLASTIC '
#                                                                                            'AND '
#                                                                                            'IMMUNOMODULATING '
#                                                                                            'AGENTS/ANTINEOPLASTIC '
#                                                                                            'AGENTS/OTHER '
#                                                                                            'ANTINEOPLASTIC '
#                                                                                            'AGENTS/Protein '
#                                                                                            'kinase '
#                                                                                            'inhibitors/sorafenib'}},
#                             'totnosyns': 1,
#                             'word_pos_array': [2]},
#                            {'dependencyMet': True,
#                             'dictSynList': ['phylloquinone',
#                                             'vitamin k1',
#                                             'phylloquinone',
#                                             'vitamin k1',
#                                             'vitamin k1',
#                                             'vitamin k1'],
#                             'docID': 'Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a43a-14879',
#                             'docTitle': '',
#                             'entityMeta': {'_ext_name': 'ChEMBL',
#                                            '_ext_uri': 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1550',
#                                            'parent_canonical_smiles': 'CC(C)CCC[C@@H](C)CCC[C@@H](C)CCC\\C(=C\\CC1=C(C)C(=O)c2ccccc2C1=O)\\C',
#                                            'parent_std_inchi': 'InChI=1S/C31H46O2/c1-22(2)12-9-13-23(3)14-10-15-24(4)16-11-17-25(5)20-21-27-26(6)30(32)28-18-7-8-19-29(28)31(27)33/h7-8,18-20,22-24H,9-17,21H2,1-6H3/b25-20+/t23-,24-/m1/s1',
#                                            'parent_std_inchi_key': 'MBWXNTAXLNYFJB-NKFFZRIASA-N'},
#                             'entityType': 'DRUG',
#                             'exact_array': [{'fls': [4, 573, 586]},
#                                             {'fls': [4, 618, 628]},
#                                             {'fls': [6, 869, 882]},
#                                             {'fls': [7, 1033, 1043]},
#                                             {'fls': [8, 1147, 1157]},
#                                             {'fls': [8, 1235, 1245]}],
#                             'exact_string': '4#573-586,4#618-628,6#869-882,7#1033-1043,8#1147-1157,8#1235-1245',
#                             'frag_vector_array': ['4#{!Phylloquinone!} (Table '
#                                                   '2, Row 4) is a vi',
#                                                   '4#2, Row 4) is a vitamin '
#                                                   '({!vitamin K1!}) supplement '
#                                                   'rather than',
#                                                   '6#their intake of dietary '
#                                                   '{!phylloquinone!} might '
#                                                   'have a lower risk',
#                                                   '7#in Table 2 suggest that '
#                                                   '{!vitamin K1!} might '
#                                                   'actually help prev',
#                                                   '8#ial cancer prevention by '
#                                                   '{!vitamin K1!} is '
#                                                   'especially intriguing',
#                                                   '8#an 1,000% daily value of '
#                                                   '{!vitamin K1!} by simply '
#                                                   'eating one cup'],
#                             'fuzzyMatches': 0,
#                             'goodSynCount': 6,
#                             'hitCount': 6,
#                             'hitID': 'CHEMBL1550',
#                             'hit_loc_vector': [4, 4, 6, 7, 8, 8],
#                             'invalidPositions': False,
#                             'kvp': {'entityType': 'DRUG'},
#                             'mappings': ['DRUGBANK|DB01022|xRef',
#                                          'SCIBITE|DRUG:CHEMBL1550|seeAlso',
#                                          'INCHIKEY|MBWXNTAXLNYFJBNKFFZRIASAN|xRef',
#                                          'SMILES|CCCCCCCHCCCCCHCCCCCCCC1CCCOc2ccccc2C1OC|xRef',
#                                          'CHEMSPIDER|4447652|xRef',
#                                          'PDB|PQN|xRef'],
#                             'name': 'Phytomenadione',
#                             'nonambigsyns': 2,
#                             'realSynList': ['Phylloquinone',
#                                             'vitamin K1',
#                                             'phylloquinone',
#                                             'vitamin K1',
#                                             'vitamin K1',
#                                             'vitamin K1'],
#                             'rejected': False,
#                             'score': 4,
#                             'sourceID': '',
#                             'sourceTitle': '',
#                             'subsume': [False,
#                                         False,
#                                         False,
#                                         False,
#                                         False,
#                                         False],
#                             'synState': [1, 1, 1, 1, 1, 1],
#                             'taxon': {'CHEMBLATC': {'CHEMBL_ATC/B/B02/B02B/B02BA/B02BA01': 'CHEMBL_ATC/BLOOD '
#                                                                                            'AND '
#                                                                                            'BLOOD '
#                                                                                            'FORMING '
#                                                                                            'ORGANS/ANTIHEMORRHAGICS/VITAMIN '
#                                                                                            'K '
#                                                                                            'AND '
#                                                                                            'OTHER '
#                                                                                            'HEMOSTATICS/Vitamin '
#                                                                                            'K/phytomenadione'}},
#                             'totnosyns': 2,
#                             'word_pos_array': [0, 8, 13, 11, 5, 21]},
#                            {'dependencyMet': True,
#                             'dictSynList': ['clopidogrel', 'clopidogrel'],
#                             'docID': 'Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a43a-14879',
#                             'docTitle': '',
#                             'entityMeta': {'_ext_name': 'ChEMBL',
#                                            '_ext_uri': 'https://www.ebi.ac.uk/chembl/compound/inspect/CHEMBL1771',
#                                            'parent_canonical_smiles': 'COC(=O)[C@@H](N1CCc2sccc2C1)c3ccccc3Cl',
#                                            'parent_std_inchi': 'InChI=1S/C16H16ClNO2S/c1-20-16(19)15(12-4-2-3-5-13(12)17)18-8-6-14-11(10-18)7-9-21-14/h2-5,7,9,15H,6,8,10H2,1H3/t15-/m0/s1',
#                                            'parent_std_inchi_key': 'GKTWGGQPFAXNFI-HNNXBMFYSA-N'},
#                             'entityType': 'DRUG',
#                             'exact_array': [{'fls': [1, 103, 114]},
#                                             {'fls': [1, 178, 189]}],
#                             'exact_string': '1#103-114,1#178-189',
#                             'frag_vector_array': ['1#colon cancer (note that '
#                                                   '{!Clopidogrel!} is in both '
#                                                   'the Drug and',
#                                                   '1#o we did not investigate '
#                                                   '{!Clopidogrel!} further).'],
#                             'fuzzyMatches': 0,
#                             'goodSynCount': 2,
#                             'hitCount': 2,
#                             'hitID': 'CHEMBL1771',
#                             'hit_loc_vector': [1, 1],
#                             'invalidPositions': False,
#                             'kvp': {'entityType': 'DRUG'},
#                             'mappings': ['DRUGBANK|DB00758|xRef',
#                                          'SCIBITE|DRUG:CHEMBL1771|seeAlso',
#                                          'INCHIKEY|GKTWGGQPFAXNFIHNNXBMFYSAN|xRef',
#                                          'PHARMGKB|PA449053|xRef',
#                                          'SMILES|COCOCHN1CCc2sccc2C1c3ccccc3Cl|xRef',
#                                          'IUPHAR|1772|xRef',
#                                          'CHEMSPIDER|54632|xRef',
#                                          'PDB|CGE|xRef'],
#                             'name': 'Clopidogrel Bisulfate',
#                             'nonambigsyns': 1,
#                             'realSynList': ['Clopidogrel', 'Clopidogrel'],
#                             'rejected': False,
#                             'score': 1,
#                             'sourceID': '',
#                             'sourceTitle': '',
#                             'subsume': [False, False],
#                             'synState': [1, 1],
#                             'taxon': {'CHEMBLATC': {'CHEMBL_ATC/B/B01/B01A/B01AC/B01AC04': 'CHEMBL_ATC/BLOOD '
#                                                                                            'AND '
#                                                                                            'BLOOD '
#                                                                                            'FORMING '
#                                                                                            'ORGANS/ANTITHROMBOTIC '
#                                                                                            'AGENTS/ANTITHROMBOTIC '
#                                                                                            'AGENTS/Platelet '
#                                                                                            'aggregation '
#                                                                                            'inhibitors '
#                                                                                            'excl. '
#                                                                                            'heparin/clopidogrel'}},
#                             'totnosyns': 1,
#                             'word_pos_array': [19, 33]}],
#                   'INDICATION': [{'dependencyMet': True,
#                                   'dictSynList': ['pancreatic cancer'],
#                                   'docID': 'Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a43a-14879',
#                                   'docTitle': '',
#                                   'entityMeta': {'_ext_name': 'MESH',
#                                                  '_ext_uri': 'http://www.nlm.nih.gov/cgi/mesh/2013/MB_cgi?field=uid&term=D010190',
#                                                  'mesh_tree': 'C06.689.667;C06.301.761;C04.588.274.761;C04.588.322.475;C19.344.421'},
#                                   'entityType': 'INDICATION',
#                                   'exact_array': [{'fls': [5, 723, 740]}],
#                                   'exact_string': '5#723-740',
#                                   'frag_vector_array': ['5#nduce apoptosis in '
#                                                         'human {!pancreatic '
#                                                         'cancer!} cell lines '
#                                                         '(Wei, Wang &'],
#                                   'fuzzyMatches': 0,
#                                   'goodSynCount': 1,
#                                   'hitCount': 1,
#                                   'hitID': 'D010190',
#                                   'hit_loc_vector': [5],
#                                   'invalidPositions': False,
#                                   'kvp': {'entityType': 'INDICATION'},
#                                   'mappings': ['EFO|EFO0002618|xRef',
#                                                'EFO|EFO0003860|xRef',
#                                                'SNOMED|126859007|xRef',
#                                                'SNOMED|154476001|xRef',
#                                                'SNOMED|154477005|xRef',
#                                                'SNOMED|154478000|xRef',
#                                                'SNOMED|187791002|xRef',
#                                                'SNOMED|187792009|xRef',
#                                                'SNOMED|187796007|xRef',
#                                                'SNOMED|269553001|xRef',
#                                                'SNOMED|269554007|xRef',
#                                                'SNOMED|269555008|xRef',
#                                                'SNOMED|363419009|xRef',
#                                                'SNOMED|93715005|xRef',
#                                                'SNOMED|93823001|xRef',
#                                                'SNOMED|94082003|xRef',
#                                                'HDO|DOID:1793|xRef',
#                                                'SCIBITE|INDICATION:D010190|seeAlso',
#                                                'OMIM|260350|xRef',
#                                                'OMIM|606856|xRef',
#                                                'OMIM|613347|xRef',
#                                                'OMIM|613348|xRef',
#                                                'OMIM|606719|narrower',
#                                                'UMLS|C0030297|xRef',
#                                                'UMLS|C0153458|xRef',
#                                                'UMLS|C0153459|xRef',
#                                                'UMLS|C0153460|xRef',
#                                                'UMLS|C0153463|xRef',
#                                                'UMLS|C0030297|xRef',
#                                                'ICD10CM|C25.0|xref',
#                                                'ICD10CM|C25.1|xref',
#                                                'ICD10CM|C25.2|xref'],
#                                   'name': 'Pancreatic Neoplasms',
#                                   'nonambigsyns': 1,
#                                   'realSynList': ['pancreatic cancer'],
#                                   'rejected': False,
#                                   'score': 1,
#                                   'sourceID': '',
#                                   'sourceTitle': '',
#                                   'subsume': [False],
#                                   'synState': [1],
#                                   'taxon': {'MESHIND': {'MESHIND/C04/C04.588/C04.588.274/C04.588.274.761': 'MESHIND/Neoplasms/Neoplasms '
#                                                                                                            'by '
#                                                                                                            'Site/Digestive '
#                                                                                                            'System '
#                                                                                                            'Neoplasms/Pancreatic '
#                                                                                                            'Neoplasms',
#                                                         'MESHIND/C04/C04.588/C04.588.322/C04.588.322.475': 'MESHIND/Neoplasms/Neoplasms '
#                                                                                                            'by '
#                                                                                                            'Site/Endocrine '
#                                                                                                            'Gland '
#                                                                                                            'Neoplasms/Pancreatic '
#                                                                                                            'Neoplasms',
#                                                         'MESHIND/C06/C06.301/C06.301.761': 'MESHIND/Digestive '
#                                                                                            'System '
#                                                                                            'Diseases/Digestive '
#                                                                                            'System '
#                                                                                            'Neoplasms/Pancreatic '
#                                                                                            'Neoplasms',
#                                                         'MESHIND/C06/C06.689/C06.689.667': 'MESHIND/Digestive '
#                                                                                            'System '
#                                                                                            'Diseases/Pancreatic '
#                                                                                            'Diseases/Pancreatic '
#                                                                                            'Neoplasms',
#                                                         'MESHIND/C19/C19.344/C19.344.421': 'MESHIND/Endocrine '
#                                                                                            'System '
#                                                                                            'Diseases/Endocrine '
#                                                                                            'Gland '
#                                                                                            'Neoplasms/Pancreatic '
#                                                                                            'Neoplasms'}},
#                                   'totnosyns': 1,
#                                   'word_pos_array': [7]},
#                                  {'dependencyMet': True,
#                                   'dictSynList': ['colon cancer',
#                                                   'colon cancer'],
#                                   'docID': 'Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a43a-14879',
#                                   'docTitle': '',
#                                   'entityMeta': {'_ext_name': 'MESH',
#                                                  '_ext_uri': 'http://www.nlm.nih.gov/cgi/mesh/2013/MB_cgi?field=uid&term=D015179',
#                                                  'mesh_tree': 'C04.588.274.476.411.307;C06.405.469.491.307;C06.301.371.411.307;C06.405.469.158.356;C06.405.249.411.307;C06.405.469.860.180'},
#                                   'entityType': 'INDICATION',
#                                   'exact_array': [{'fls': [1, 79, 91]},
#                                                   {'fls': [3, 559, 571]}],
#                                   'exact_string': '1#79-91,3#559-571',
#                                   'frag_vector_array': ['1#ght be useful to '
#                                                         'prevent {!colon '
#                                                         'cancer!} (note that '
#                                                         'Clopidogrel i',
#                                                         '3#epurposed '
#                                                         'prevention for '
#                                                         '{!colon cancer!}.'],
#                                   'fuzzyMatches': 0,
#                                   'goodSynCount': 2,
#                                   'hitCount': 2,
#                                   'hitID': 'D015179',
#                                   'hit_loc_vector': [1, 3],
#                                   'invalidPositions': False,
#                                   'kvp': {'entityType': 'INDICATION'},
#                                   'mappings': ['EFO|EFO0004142|xRef',
#                                                'EFO|EFO0005842|xRef',
#                                                'SNOMED|363510005|xRef',
#                                                'SNOMED|408645001|xRef',
#                                                'SNOMED|93854002|xRef',
#                                                'HDO|DOID:5672|xRef',
#                                                'HDO|DOID:9256|xRef',
#                                                'SCIBITE|INDICATION:D015179|seeAlso',
#                                                'OMIM|114500|xRef',
#                                                'OMIM|114500|xRef',
#                                                'OMIM|608812|xRef',
#                                                'OMIM|611469|xRef',
#                                                'OMIM|612229|xRef',
#                                                'OMIM|612230|xRef',
#                                                'OMIM|612231|xRef',
#                                                'OMIM|612232|xRef',
#                                                'OMIM|612589|xRef',
#                                                'OMIM|612590|xRef',
#                                                'OMIM|612591|xRef',
#                                                'OMIM|612592|xRef',
#                                                'OMIM|175100|narrower',
#                                                'OMIM|608615|narrower',
#                                                'OMIM|276300|narrower',
#                                                'UMLS|C0009402|xRef',
#                                                'UMLS|C0346629|xRef',
#                                                'UMLS|C1319315|xRef',
#                                                'UMLS|C1527249|xRef',
#                                                'UMLS|C0009404|xRef',
#                                                'ICD10CM|C18.9|xref'],
#                                   'name': 'Colorectal Neoplasms',
#                                   'nonambigsyns': 1,
#                                   'realSynList': ['colon cancer',
#                                                   'colon cancer'],
#                                   'rejected': False,
#                                   'score': 2,
#                                   'sourceID': '',
#                                   'sourceTitle': '',
#                                   'subsume': [False, False],
#                                   'synState': [1, 1],
#                                   'taxon': {'MESHIND': {'MESHIND/C04/C04.588/C04.588.274/C04.588.274.476/C04.588.274.476.411/C04.588.274.476.411.307': 'MESHIND/Neoplasms/Neoplasms '
#                                                                                                                                                        'by '
#                                                                                                                                                        'Site/Digestive '
#                                                                                                                                                        'System '
#                                                                                                                                                        'Neoplasms/Gastrointestinal '
#                                                                                                                                                        'Neoplasms/Intestinal '
#                                                                                                                                                        'Neoplasms/Colorectal '
#                                                                                                                                                        'Neoplasms',
#                                                         'MESHIND/C06/C06.301/C06.301.371/C06.301.371.411/C06.301.371.411.307': 'MESHIND/Digestive '
#                                                                                                                                'System '
#                                                                                                                                'Diseases/Digestive '
#                                                                                                                                'System '
#                                                                                                                                'Neoplasms/Gastrointestinal '
#                                                                                                                                'Neoplasms/Intestinal '
#                                                                                                                                'Neoplasms/Colorectal '
#                                                                                                                                'Neoplasms',
#                                                         'MESHIND/C06/C06.405/C06.405.249/C06.405.249.411/C06.405.249.411.307': 'MESHIND/Digestive '
#                                                                                                                                'System '
#                                                                                                                                'Diseases/Gastrointestinal '
#                                                                                                                                'Diseases/Gastrointestinal '
#                                                                                                                                'Neoplasms/Intestinal '
#                                                                                                                                'Neoplasms/Colorectal '
#                                                                                                                                'Neoplasms',
#                                                         'MESHIND/C06/C06.405/C06.405.469/C06.405.469.158/C06.405.469.158.356': 'MESHIND/Digestive '
#                                                                                                                                'System '
#                                                                                                                                'Diseases/Gastrointestinal '
#                                                                                                                                'Diseases/Intestinal '
#                                                                                                                                'Diseases/Colonic '
#                                                                                                                                'Diseases/Colorectal '
#                                                                                                                                'Neoplasms',
#                                                         'MESHIND/C06/C06.405/C06.405.469/C06.405.469.491/C06.405.469.491.307': 'MESHIND/Digestive '
#                                                                                                                                'System '
#                                                                                                                                'Diseases/Gastrointestinal '
#                                                                                                                                'Diseases/Intestinal '
#                                                                                                                                'Diseases/Intestinal '
#                                                                                                                                'Neoplasms/Colorectal '
#                                                                                                                                'Neoplasms',
#                                                         'MESHIND/C06/C06.405/C06.405.469/C06.405.469.860/C06.405.469.860.180': 'MESHIND/Digestive '
#                                                                                                                                'System '
#                                                                                                                                'Diseases/Gastrointestinal '
#                                                                                                                                'Diseases/Intestinal '
#                                                                                                                                'Diseases/Rectal '
#                                                                                                                                'Diseases/Colorectal '
#                                                                                                                                'Neoplasms'}},
#                                   'totnosyns': 1,
#                                   'word_pos_array': [15, 24]},
#                                  {'dependencyMet': True,
#                                   'dictSynList': ['anti tumor',
#                                                   'cancer',
#                                                   'cancer',
#                                                   'cancer'],
#                                   'docID': 'Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a43a-14879',
#                                   'docTitle': '',
#                                   'entityMeta': {'_ext_name': 'MESH',
#                                                  '_ext_uri': 'http://www.nlm.nih.gov/cgi/mesh/2013/MB_cgi?field=uid&term=D002277',
#                                                  'mesh_tree': 'C04.557.470.200'},
#                                   'entityType': 'INDICATION',
#                                   'exact_array': [{'fls': [2, 259, 269]},
#                                                   {'fls': [6, 910, 916]},
#                                                   {'fls': [7, 1072, 1078]},
#                                                   {'fls': [8, 1126, 1132]}],
#                                   'exact_string': '2#259-269,6#910-916,7#1072-1078,8#1126-1132',
#                                   'frag_vector_array': ['2#that Telmisartan '
#                                                         'exerts {!anti-tumor!} '
#                                                         'effects by activating '
#                                                         'pe',
#                                                         '6#ght have a lower '
#                                                         'risk of {!cancer!} '
#                                                         'than those who did '
#                                                         'not (',
#                                                         '7#ht actually help '
#                                                         'prevent {!cancer!} '
#                                                         '(OR = 0.27, 95% CI '
#                                                         '[0.07',
#                                                         '8#The potential '
#                                                         '{!cancer!} prevention '
#                                                         'by vitamin K1'],
#                                   'fuzzyMatches': 0,
#                                   'goodSynCount': 0,
#                                   'hitCount': 4,
#                                   'hitID': 'D002277',
#                                   'hit_loc_vector': [2, 6, 7, 8],
#                                   'invalidPositions': False,
#                                   'kvp': {'entityType': 'INDICATION'},
#                                   'mappings': ['EFO|EFO0000311|xRef',
#                                                'EFO|EFO0000313|xRef',
#                                                'EFO|EFO0006772|xRef',
#                                                'SNOMED|118285006|xRef',
#                                                'SNOMED|134207000|xRef',
#                                                'SNOMED|154433003|xRef',
#                                                'SNOMED|188083002|xRef',
#                                                'SNOMED|189546004|xRef',
#                                                'SNOMED|189549006|xRef',
#                                                'SNOMED|189559007|xRef',
#                                                'SNOMED|269513004|xRef',
#                                                'SNOMED|68453008|xRef',
#                                                'SNOMED|71298006|xRef',
#                                                'SNOMED|189553008|xRef',
#                                                'SNOMED|58248003|xRef',
#                                                'SNOMED|23109009|xRef',
#                                                'SNOMED|65692009|xRef',
#                                                'HDO|DOID:305|xRef',
#                                                'HDO|DOID:5651|xRef',
#                                                'HDO|DOID:4015|xRef',
#                                                'SCIBITE|INDICATION:D002277|seeAlso',
#                                                'OMIM|605462|narrower',
#                                                'OMIM|613058|narrower',
#                                                'OMIM|613059|narrower',
#                                                'OMIM|613061|narrower',
#                                                'OMIM|613062|narrower',
#                                                'OMIM|613063|narrower',
#                                                'OMIM|182280|narrower',
#                                                'OMIM|132800|narrower',
#                                                'OMIM|188550|narrower',
#                                                'UMLS|C0007097|xRef',
#                                                'UMLS|C0553707|xRef',
#                                                'UMLS|C1368683|xRef',
#                                                'UMLS|C0205696|xRef',
#                                                'UMLS|C0205697|xRef',
#                                                'UMLS|C0007097|xRef'],
#                                   'name': 'Carcinoma',
#                                   'nonambigsyns': 2,
#                                   'realSynList': ['anti-tumor',
#                                                   'cancer',
#                                                   'cancer',
#                                                   'cancer'],
#                                   'rejected': False,
#                                   'score': 4,
#                                   'sourceID': '',
#                                   'sourceTitle': '',
#                                   'subsume': [False, False, False, False],
#                                   'synState': [0, 0, 0, 0],
#                                   'taxon': {'MESHIND': {'MESHIND/C04/C04.557/C04.557.470/C04.557.470.200': 'MESHIND/Neoplasms/Neoplasms '
#                                                                                                            'by '
#                                                                                                            'Histologic '
#                                                                                                            'Type/Neoplasms, '
#                                                                                                            'Glandular '
#                                                                                                            'and '
#                                                                                                            'Epithelial/Carcinoma'}},
#                                   'totnosyns': 2,
#                                   'word_pos_array': [8, 20, 17, 2]},
#                                  {'dependencyMet': True,
#                                   'dictSynList': ['colon cancer',
#                                                   'colon cancer'],
#                                   'docID': 'Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a43a-14879',
#                                   'docTitle': '',
#                                   'entityMeta': {'_ext_name': 'MESH',
#                                                  '_ext_uri': 'http://www.nlm.nih.gov/cgi/mesh/2013/MB_cgi?field=uid&term=D003110',
#                                                  'mesh_tree': 'C04.588.274.476.411.307.180;C06.405.469.158.356.180;C06.405.469.491.307.180;C06.301.371.411.307.180;C06.405.249.411.307.180'},
#                                   'entityType': 'INDICATION',
#                                   'exact_array': [{'fls': [1, 79, 91]},
#                                                   {'fls': [3, 559, 571]}],
#                                   'exact_string': '1#79-91,3#559-571',
#                                   'frag_vector_array': ['1#ght be useful to '
#                                                         'prevent {!colon '
#                                                         'cancer!} (note that '
#                                                         'Clopidogrel i',
#                                                         '3#epurposed '
#                                                         'prevention for '
#                                                         '{!colon cancer!}.'],
#                                   'fuzzyMatches': 0,
#                                   'goodSynCount': 2,
#                                   'hitCount': 2,
#                                   'hitID': 'D003110',
#                                   'hit_loc_vector': [1, 3],
#                                   'invalidPositions': False,
#                                   'kvp': {'entityType': 'INDICATION'},
#                                   'mappings': ['EFO|EFO0004288|xRef',
#                                                'EFO|EFO0005842|xRef',
#                                                'ICD9|153|xRef',
#                                                'ICD9|1539|xRef',
#                                                'SNOMED|126838000|xRef',
#                                                'SNOMED|154463007|xRef',
#                                                'SNOMED|187759003|xRef',
#                                                'SNOMED|269461008|xRef',
#                                                'SNOMED|269542007|xRef',
#                                                'SNOMED|363406005|xRef',
#                                                'SNOMED|93761005|xRef',
#                                                'HDO|DOID:235|xRef',
#                                                'HDO|DOID:219|xRef',
#                                                'SCIBITE|INDICATION:D003110|seeAlso',
#                                                'OMIM|175100|narrower',
#                                                'UMLS|C0009375|xRef',
#                                                'UMLS|C0007102|xRef',
#                                                'UMLS|C0009375|xRef',
#                                                'ICD10CM|C18|xref',
#                                                'ICD10CM|C18.9|xref'],
#                                   'name': 'Colonic Neoplasms',
#                                   'nonambigsyns': 1,
#                                   'realSynList': ['colon cancer',
#                                                   'colon cancer'],
#                                   'rejected': False,
#                                   'score': 2,
#                                   'sourceID': '',
#                                   'sourceTitle': '',
#                                   'subsume': [False, False],
#                                   'synState': [1, 1],
#                                   'taxon': {'MESHIND': {'MESHIND/C04/C04.588/C04.588.274/C04.588.274.476/C04.588.274.476.411/C04.588.274.476.411.307/C04.588.274.476.411.307.180': 'MESHIND/Neoplasms/Neoplasms '
#                                                                                                                                                                                    'by '
#                                                                                                                                                                                    'Site/Digestive '
#                                                                                                                                                                                    'System '
#                                                                                                                                                                                    'Neoplasms/Gastrointestinal '
#                                                                                                                                                                                    'Neoplasms/Intestinal '
#                                                                                                                                                                                    'Neoplasms/Colorectal '
#                                                                                                                                                                                    'Neoplasms/Colonic '
#                                                                                                                                                                                    'Neoplasms',
#                                                         'MESHIND/C06/C06.301/C06.301.371/C06.301.371.411/C06.301.371.411.307/C06.301.371.411.307.180': 'MESHIND/Digestive '
#                                                                                                                                                        'System '
#                                                                                                                                                        'Diseases/Digestive '
#                                                                                                                                                        'System '
#                                                                                                                                                        'Neoplasms/Gastrointestinal '
#                                                                                                                                                        'Neoplasms/Intestinal '
#                                                                                                                                                        'Neoplasms/Colorectal '
#                                                                                                                                                        'Neoplasms/Colonic '
#                                                                                                                                                        'Neoplasms',
#                                                         'MESHIND/C06/C06.405/C06.405.249/C06.405.249.411/C06.405.249.411.307/C06.405.249.411.307.180': 'MESHIND/Digestive '
#                                                                                                                                                        'System '
#                                                                                                                                                        'Diseases/Gastrointestinal '
#                                                                                                                                                        'Diseases/Gastrointestinal '
#                                                                                                                                                        'Neoplasms/Intestinal '
#                                                                                                                                                        'Neoplasms/Colorectal '
#                                                                                                                                                        'Neoplasms/Colonic '
#                                                                                                                                                        'Neoplasms',
#                                                         'MESHIND/C06/C06.405/C06.405.469/C06.405.469.158/C06.405.469.158.356/C06.405.469.158.356.180': 'MESHIND/Digestive '
#                                                                                                                                                        'System '
#                                                                                                                                                        'Diseases/Gastrointestinal '
#                                                                                                                                                        'Diseases/Intestinal '
#                                                                                                                                                        'Diseases/Colonic '
#                                                                                                                                                        'Diseases/Colorectal '
#                                                                                                                                                        'Neoplasms/Colonic '
#                                                                                                                                                        'Neoplasms',
#                                                         'MESHIND/C06/C06.405/C06.405.469/C06.405.469.491/C06.405.469.491.307/C06.405.469.491.307.180': 'MESHIND/Digestive '
#                                                                                                                                                        'System '
#                                                                                                                                                        'Diseases/Gastrointestinal '
#                                                                                                                                                        'Diseases/Intestinal '
#                                                                                                                                                        'Diseases/Intestinal '
#                                                                                                                                                        'Neoplasms/Colorectal '
#                                                                                                                                                        'Neoplasms/Colonic '
#                                                                                                                                                        'Neoplasms'}},
#                                   'totnosyns': 1,
#                                   'word_pos_array': [15, 24]}]},
#  'RESP_WARNINGS': None}

# %% [markdown]
# To understand the JSON output of TERMite results [click here](https://help.scibite.com/a/solutions/articles/179705-anatomy-of-a-termite-hit).
#
# Use ```help(termite.TermiteRequestBuilder)``` to view the documentation to see the available functions of ```TermiteRequestBuilder()``` and how they can be used to set the runtime options.

# %% [markdown]
# Once familiar with making a call in Python you'll be able to make calls on files and using a python dict object of TERMite options (these can be viewed on your TERMite server homepage), like the example below:

# %%
from pprint import pprint
from termite_toolkit import termite
import sys
import os

# specify termite API endpoint
termite_home = "http://localhost:9090/termite"

# input file
parentDir = os.path.dirname(os.path.dirname(os.path.abspath("__file__")))  # this line relatively locates the parent directory
input_file = os.path.join(parentDir, 'sample_scripts/medline_sample.zip')  

# TERMite options
options = {"format": "medline.xml", "output": "json", "entities": "DRUG,GENE,INDICATION"}

# TERMite call as JSON result
termite_json_response = termite.annotate_files(termite_home, input_file, options)

# %% [markdown]
# ## TERMite toolkit library

# %% [markdown]
# The standard JSON output is gives the most rich output, but this isn't the most human friendly.
#
# The TERMite toolkit has many built-in functions for parsing outputs. For example, ```get_entitiy_hits_from_json()``` takes a JSON TERMite response and returns a summary of the hits with additional filtering rules applied. The returned object is a python dict object indexed by entity ID, with associated frequency counts.
#
# Below is an example of post-processing of the results from our first TERMite example call; we've filtered the TERMite hits so that we're only looking at DRUG hits.

# %%
filtered_hits = termite.get_entity_hits_from_json(termite_response, 'DRUG', reject_ambig=False)

pprint(filtered_hits)
# Out:
# {'DRUG$CHEMBL1017': {'doc_count': 1,
#                      'doc_id': [''],
#                      'hit_count': 3,
#                      'id': 'CHEMBL1017',
#                      'max_relevance_score': 4,
#                      'name': 'Telmisartan',
#                      'type': 'DRUG'},
#  'DRUG$CHEMBL1336': {'doc_count': 1,
#                      'doc_id': [''],
#                      'hit_count': 1,
#                      'id': 'CHEMBL1336',
#                      'max_relevance_score': 1,
#                      'name': 'BAY43-9006',
#                      'type': 'DRUG'},
#  'DRUG$CHEMBL1550': {'doc_count': 1,
#                      'doc_id': [''],
#                      'hit_count': 6,
#                      'id': 'CHEMBL1550',
#                      'max_relevance_score': 4,
#                      'name': 'Phytomenadione',
#                      'type': 'DRUG'},
#  'DRUG$CHEMBL1771': {'doc_count': 1,
#                      'doc_id': [''],
#                      'hit_count': 2,
#                      'id': 'CHEMBL1771',
#                      'max_relevance_score': 1,
#                      'name': 'Clopidogrel Bisulfate',
#                      'type': 'DRUG'}}

# %% [markdown]
# We've also added functionality to convert the json and doc.JSONx outputs into a pandas dataframe, either by individual hits or grouped by TERMite ID.

# %%
termite.get_termite_dataframe(termite_response, reject_ambig = False).head()
# Out:
#                                                docID  entityType       hitID  \
# 0  Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a4...        DRUG  CHEMBL1017
# 1  Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a4...        DRUG  CHEMBL1336
# 2  Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a4...        DRUG  CHEMBL1550
# 3  Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a4...        DRUG  CHEMBL1771
# 4  Termite_Doc_d70829d1-bc8f-44ce-a2ee-39a19321a4...  INDICATION     D010190
#
#                     name  score  \
# 0            Telmisartan      4
# 1             BAY43-9006      1
# 2         Phytomenadione      4
# 3  Clopidogrel Bisulfate      1
# 4   Pancreatic Neoplasms      1
#
#                                          realSynList  totnosyns  nonambigsyns  \
# 0            [Telmisartan, Telmisartan, Telmisartan]          1             1
# 1                                        [sorafenib]          1             1
# 2  [Phylloquinone, vitamin K1, phylloquinone, vit...          2             2
# 3                         [Clopidogrel, Clopidogrel]          1             1
# 4                                [pancreatic cancer]          1             1
#
#                                    frag_vector_array  hitCount
# 0  [1#le 2, Row 2 suggest that {!Telmisartan!} mi...         3
# 1  [5#K vitamins + {!sorafenib!} induce apoptosis...         1
# 2  [4#{!Phylloquinone!} (Table 2, Row 4) is a vi,...         6
# 3  [1#colon cancer (note that {!Clopidogrel!} is ...         2
# 4  [5#nduce apoptosis in human {!pancreatic cance...         1

# %%
termite.all_entities_df(termite_json_response).head()
# Out:
#               doc_count                                             doc_id  \
# DRUG$CHEMBL38         1                                         [25987350]
# GENE$CD4              9  [25987350, 24793818, 23523417, 22995775, 23021...
# GENE$TGFB1            7  [25987350, 22578910, 23403039, 22974822, 23643...
# GENE$IL2RA            4           [25987350, 23643066, 26589955, 24411923]
# GENE$FOXP3            5  [25987350, 23523417, 23643066, 26589955, 24411...
#
#               hit_count        id max_relevance_score  \
# DRUG$CHEMBL38         5  CHEMBL38                   5
# GENE$CD4             38       CD4                   5
# GENE$TGFB1           22     TGFB1                   5
# GENE$IL2RA            9     IL2RA                   4
# GENE$FOXP3           10     FOXP3                   5
#
#                                                name  type
# DRUG$CHEMBL38                             Tretinoin  DRUG
# GENE$CD4                               CD4 molecule  GENE
# GENE$TGFB1        transforming growth factor beta 1  GENE
# GENE$IL2RA     interleukin 2 receptor subunit alpha  GENE
# GENE$FOXP3                          forkhead box P3  GENE

# %% [markdown]
# We've made it easier to identify which VOCabs have hits within the TERMite input, their frequencies, and the most frequent hits:

# %%
termite.all_entities(termite_json_response)
# Out:
# ['DRUG', 'GENE', 'INDICATION']

# %%
termite.entity_freq(termite_json_response)
# Out:
#             entityType
# INDICATION        3168
# DRUG               573
# GENE               530

# %%
top_hits_df(termite_json_response, selection=5)
# Out:
#                                id                         name        type  \
# INDICATION$D003424        D003424                Crohn Disease  INDICATION
# INDICATION$D003093        D003093          Colitis, Ulcerative  INDICATION
# INDICATION$D015212        D015212  Inflammatory Bowel Diseases  INDICATION
# INDICATION$D007249        D007249                 Inflammation  INDICATION
# DRUG$CHEMBL1201581  CHEMBL1201581                       TA-650        DRUG
#
#                    hit_count
# INDICATION$D003424      2084
# INDICATION$D003093      1509
# INDICATION$D015212      1000
# INDICATION$D007249       468
# DRUG$CHEMBL1201581       369
